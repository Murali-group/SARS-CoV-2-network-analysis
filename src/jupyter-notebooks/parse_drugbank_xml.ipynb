# %% [markdown]
# ## DrugBank Parser test
# https://github.com/dhimmel/drugbank/blob/gh-pages/parse.ipynb

# %%
import os
import csv
import gzip
import zipfile
import collections
import re
import io
import json
import xml.etree.ElementTree as ET

import requests
import pandas
import pandas as pd

# %%
os.getcwd()
# Out:
# '/data/jeff-law/projects/2020-03-covid-19/SARS-CoV-2-network-analysis/src/jupyter-notebooks'

# %%
xml_file = "/data/jeff-law/projects/2020-03-covid-19/SARS-CoV-2-network-analysis/datasets/drug-targets/drugbank-v5.1.6/additional-data/drugbank_all_full_database.xml.zip"
with zipfile.ZipFile(xml_file) as myzip:
    with myzip.open("full database.xml") as f:
        tree = ET.parse(f)
root = tree.getroot()

# %%
ns = '{http://www.drugbank.ca}'
inchikey_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChIKey']/{ns}value"
inchi_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChI']/{ns}value"

rows = list()
for i, drug in enumerate(root):
    row = collections.OrderedDict()
    assert drug.tag == ns + 'drug'
    row['type'] = drug.get('type')
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name")
    row['description'] = drug.findtext(ns + "description")
    row['groups'] = [group.text for group in
        drug.findall("{ns}groups/{ns}group".format(ns = ns))]
    row['atc_codes'] = [code.get('code') for code in
        drug.findall("{ns}atc-codes/{ns}atc-code".format(ns = ns))]
    row['categories'] = [x.findtext(ns + 'category') for x in
        drug.findall("{ns}categories/{ns}category".format(ns = ns))]
    row['inchi'] = drug.findtext(inchi_template.format(ns = ns))
    row['inchikey'] = drug.findtext(inchikey_template.format(ns = ns))
    # extract some additional data
    row['indication'] = drug.findtext(ns + "indication")
    row['pharmacodynamics'] = drug.findtext(ns + "pharmacodynamics")
    row['mechanism-of-action'] = drug.findtext(ns + "mechanism-of-action")
    row['toxicity'] = drug.findtext(ns + "toxicity")
    row['protein-binding'] = drug.findtext(ns + "protein-binding")
    
    # Add drug aliases
    aliases = {
        elem.text for elem in 
        drug.findall("{ns}international-brands/{ns}international-brand".format(ns = ns)) +
        drug.findall("{ns}synonyms/{ns}synonym[@language='English']".format(ns = ns)) +
        drug.findall("{ns}international-brands/{ns}international-brand".format(ns = ns)) +
        drug.findall("{ns}products/{ns}product/{ns}name".format(ns = ns))

    }
    aliases.add(row['name'])
    row['aliases'] = sorted(aliases)

    rows.append(row)

# %%
alias_dict = {row['drugbank_id']: row['aliases'] for row in rows}
with open('./aliases.json', 'w') as fp:
    json.dump(alias_dict, fp, indent=2, sort_keys=True)

# %%
def collapse_list_values(row):
    for key, value in row.items():
        if isinstance(value, list):
            row[key] = '|'.join(value)
    return row

rows = list(map(collapse_list_values, rows))

# %%
columns = ['drugbank_id', 'name', 'type', 'groups', 'atc_codes', 'categories', 'inchikey', 'inchi', 'description']
drugbank_df = pandas.DataFrame.from_dict(rows)[columns]
drugbank_df.head()
# Out:
#   drugbank_id                 name     type                    groups  \
# 0     DB00001            Lepirudin  biotech                  approved
# 1     DB00002            Cetuximab  biotech                  approved
# 2     DB00003         Dornase alfa  biotech                  approved
# 3     DB00004  Denileukin diftitox  biotech  approved|investigational
# 4     DB00005           Etanercept  biotech  approved|investigational
#
#   atc_codes                                         categories inchikey inchi  \
# 0   B01AE02  Amino Acids, Peptides, and Proteins|Anticoagul...     None  None
# 1   L01XC06  Amino Acids, Peptides, and Proteins|Antibodies...     None  None
# 2   R05CB13  Amino Acids, Peptides, and Proteins|Cough and ...     None  None
# 3   L01XX29  ADP Ribose Transferases|Amino Acids, Peptides,...     None  None
# 4   L04AB01  Agents reducing cytokine levels|Amino Acids, P...     None  None
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
drugbank_slim_df = drugbank_df[
    drugbank_df.groups.map(lambda x: 'approved' in x) &
    drugbank_df.inchi.map(lambda x: x is not None) &
    drugbank_df.type.map(lambda x: x == 'small molecule')
]
drugbank_slim_df.head()
# Out:
#    drugbank_id          name            type                    groups  \
# 5      DB00006   Bivalirudin  small molecule  approved|investigational
# 6      DB00007    Leuprolide  small molecule  approved|investigational
# 13     DB00014     Goserelin  small molecule                  approved
# 25     DB00027  Gramicidin D  small molecule                  approved
# 33     DB00035  Desmopressin  small molecule                  approved
#
#           atc_codes                                         categories  \
# 5           B01AE06  Amino Acids, Peptides, and Proteins|Anticoagul...
# 6   L02AE51|L02AE02  Adrenal Cortex Hormones|Agents Causing Muscle ...
# 13          L02AE03  Adrenal Cortex Hormones|Amino Acids, Peptides,...
# 25          R02AB30  Amino Acids, Peptides, and Proteins|Anti-Bacte...
# 33          H01BA02  Agents that produce hypertension|Amino Acids, ...
#
#                        inchikey  \
# 5   OIRCOABEOLEUMC-GEJPAHFPSA-N
# 6   GFIJNRVAKGFPGQ-LIJARHBVSA-N
# 13  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 25  NDAYQJDHGXTBJL-MWWSRJDJSA-N
# 33  NFLWUMRGJYTJIN-PNIOQBSNSA-N
#
#                                                 inchi  \
# 5   InChI=1S/C98H138N24O33/c1-5-52(4)82(96(153)122...
# 6   InChI=1S/C59H84N16O12/c1-6-63-57(86)48-14-10-2...
# 13  InChI=1S/C59H84N18O14/c1-31(2)22-40(49(82)68-3...
# 25  InChI=1S/C96H135N19O16/c1-50(2)36-71(105-79(11...
# 33  InChI=1S/C46H64N14O12S2/c47-35(62)15-14-29-40(...
#
#                                           description
# 5   Bivalirudin is a synthetic 20 residue peptide ...
# 6   Leuprolide belongs to the general class of dru...
# 13  Goserelin is a synthetic hormone. In men, it s...
# 25  Gramcidin D is a heterogeneous mixture of thre...
# 33  Desmopressin (dDAVP), a synthetic analogue of ...

# %%
# write drugbank tsv
path = os.path.join('data', 'drugbank.tsv')
drugbank_df.to_csv(path, sep='\t', index=False)

# write slim drugbank tsv
path = os.path.join('data', 'drugbank-slim.tsv')
drugbank_slim_df.to_csv(path, sep='\t', index=False)

# %%
# also get the extra information per drug
columns = ['drugbank_id', 'name', 'indication', 'pharmacodynamics', 'mechanism-of-action', 'toxicity', 'protein-binding']
drugbank_df2 = pandas.DataFrame.from_dict(rows)[columns]
drugbank_df2.head()
# Out:
#   drugbank_id                 name  \
# 0     DB00001            Lepirudin
# 1     DB00002            Cetuximab
# 2     DB00003         Dornase alfa
# 3     DB00004  Denileukin diftitox
# 4     DB00005           Etanercept
#
#                                           indication  \
# 0  For the treatment of heparin-induced thrombocy...
# 1  Cetuximab, used in combination with irinotecan...
# 2  Used as adjunct therapy in the treatment of cy...
# 3         For treatment of cutaneous T-cell lymphoma
# 4  Etanercept is indicated for the treatment of m...
#
#                                     pharmacodynamics  \
# 0  Lepirudin is used to break up clots and to red...
# 1  Used in the treatment of colorectal cancer, ce...
# 2  Cystic fibrosis (CF) is a disease characterize...
# 3  Denileukin diftitox (Ontak) directs the cytoci...
# 4  Etanercept binds specifically to tumor necrosi...
#
#                                  mechanism-of-action  \
# 0  Lepirudin forms a stable non-covalent complex ...
# 1  Cetuximab binds to the epidermal growth factor...
# 2  Dornase alfa is a biosynthetic form of human D...
# 3  Denileukin diftitox binds to the high-affinity...
# 4  There are two distinct receptors for TNF (TNFR...
#
#                                             toxicity protein-binding
# 0  In case of overdose (eg, suggested by excessiv...
# 1  Pulmonary Toxicity\r\n\r\nInterstitial lung di...
# 2  Adverse reactions occur at a frequency of < 1/...
# 3
# 4

# %%
path = os.path.join('data', 'drugbank-toxicity.tsv')
drugbank_df2.to_csv(path, sep='\t', index=False)

# %%
df = pd.read_csv(path, sep='\t')
df.head()
# Out:
#   drugbank_id          name            type                    groups  \
# 0     DB00006   Bivalirudin  small molecule  approved|investigational
# 1     DB00007    Leuprolide  small molecule  approved|investigational
# 2     DB00014     Goserelin  small molecule                  approved
# 3     DB00027  Gramicidin D  small molecule                  approved
# 4     DB00035  Desmopressin  small molecule                  approved
#
#          atc_codes                                         categories  \
# 0          B01AE06  Amino Acids, Peptides, and Proteins|Anticoagul...
# 1  L02AE51|L02AE02  Adrenal Cortex Hormones|Agents Causing Muscle ...
# 2          L02AE03  Adrenal Cortex Hormones|Amino Acids, Peptides,...
# 3          R02AB30  Amino Acids, Peptides, and Proteins|Anti-Bacte...
# 4          H01BA02  Agents that produce hypertension|Amino Acids, ...
#
#                       inchikey  \
# 0  OIRCOABEOLEUMC-GEJPAHFPSA-N
# 1  GFIJNRVAKGFPGQ-LIJARHBVSA-N
# 2  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 3  NDAYQJDHGXTBJL-MWWSRJDJSA-N
# 4  NFLWUMRGJYTJIN-PNIOQBSNSA-N
#
#                                                inchi  \
# 0  InChI=1S/C98H138N24O33/c1-5-52(4)82(96(153)122...
# 1  InChI=1S/C59H84N16O12/c1-6-63-57(86)48-14-10-2...
# 2  InChI=1S/C59H84N18O14/c1-31(2)22-40(49(82)68-3...
# 3  InChI=1S/C96H135N19O16/c1-50(2)36-71(105-79(11...
# 4  InChI=1S/C46H64N14O12S2/c47-35(62)15-14-29-40(...
#
#                                          description
# 0  Bivalirudin is a synthetic 20 residue peptide ...
# 1  Leuprolide belongs to the general class of dru...
# 2  Goserelin is a synthetic hormone. In men, it s...
# 3  Gramcidin D is a heterogeneous mixture of thre...
# 4  Desmopressin (dDAVP), a synthetic analogue of ...

# %%
drugbank_df['type'].value_counts()
# Out:
# small molecule    11355
# biotech            2120
# Name: type, dtype: int64

# %%
df[df['drugbank_id'] == "DB15091"]
# Out:
#      drugbank_id          name            type                    groups  \
# 2579     DB15091  Upadacitinib  small molecule  approved|investigational
#
#      atc_codes                                         categories  \
# 2579       NaN  Antirheumatic Agents|BCRP/ABCG2 Inhibitors|BCR...
#
#                          inchikey  \
# 2579  WYQFJHHDOKWSHR-MNOVXSKESA-N
#
#                                                   inchi  \
# 2579  InChI=1S/C17H19F3N6O/c1-2-10-7-25(16(27)24-9-1...
#
#                                             description
# 2579  Upadacitinib is an oral Janus kinase (JAK)1-se...

# %% [markdown]
# ## Extract protein information

# %%
protein_rows = list()
for i, drug in enumerate(root):
    drugbank_id = drug.findtext(ns + "drugbank-id[@primary='true']")
    name= drug.findtext(ns + "name")
    for category in ['target', 'enzyme', 'carrier', 'transporter']:
        proteins = drug.findall('{ns}{cat}s/{ns}{cat}'.format(ns=ns, cat=category))
        for protein in proteins:
            row = {'drugbank_id': drugbank_id, 'name': name, 'category': category}
            row['organism'] = protein.findtext('{}organism'.format(ns))
            row['known_action'] = protein.findtext('{}known-action'.format(ns))
            actions = protein.findall('{ns}actions/{ns}action'.format(ns=ns))
            row['actions'] = '|'.join(action.text for action in actions)
            uniprot_ids = [polypep.text for polypep in protein.findall(
                "{ns}polypeptide/{ns}external-identifiers/{ns}external-identifier[{ns}resource='UniProtKB']/{ns}identifier".format(ns=ns))]            
            if len(uniprot_ids) != 1:
                continue
            row['uniprot_id'] = uniprot_ids[0]
            pmids = []
            citations = []
            references = protein.find('{http://www.drugbank.ca}references')
            if references is not None:
                for article in references.find('{http://www.drugbank.ca}articles'):
                    pmid = article.find('{http://www.drugbank.ca}pubmed-id').text
                    text = article.find('{http://www.drugbank.ca}citation').text
    #                 evidence.append({'source': 'DrugBank', 'pmid': pmid, 'text': text})
                    if pmid is not None:
                        pmids.append(pmid)
                        citations.append(text)
            if len(pmids) > 0:
                row['pubmed_ids'] = '|'.join(pmids)
                row['citations'] = '|'.join(citations)
        
#             pmids = protein.findall("{ns}references/{ns}articles/{ns}article/{ns}pubmed-id".format(ns=ns))
#             if pmids is not None:
#                 row['pubmed_ids'] = '|'.join(pmid.text for pmid in pmids if pmid.text is not None)
            protein_rows.append(row)
#     break

protein_df = pandas.DataFrame.from_dict(protein_rows)
protein_df.head()
# Out:
#   drugbank_id       name category organism known_action     actions  \
# 0     DB00001  Lepirudin   target   Humans          yes   inhibitor
# 1     DB00002  Cetuximab   target   Humans          yes  antagonist
# 2     DB00002  Cetuximab   target   Humans      unknown
# 3     DB00002  Cetuximab   target   Humans      unknown
# 4     DB00002  Cetuximab   target   Humans      unknown
#
#   uniprot_id                                         pubmed_ids  \
# 0     P00734  10505536|10912644|11055889|11467439|11807012|1...
# 1     P00533  10480573|10601294|10628369|11408594|11431346|1...
# 2     O75015                                           16336752
# 3     P00736                                  17139284|17016423
# 4     P02745                                  17139284|17016423
#
#                                            citations
# 0  Turpie AG: Anticoagulants in acute coronary sy...
# 1  Hosokawa N, Yamamoto S, Uehara Y, Hori M, Tsuc...
# 2  Snyder LC, Astsaturov I, Weiner LM: Overview o...
# 3  Overington JP, Al-Lazikani B, Hopkins AL: How ...
# 4  Overington JP, Al-Lazikani B, Hopkins AL: How ...

# %%
path = os.path.join('data', 'drugbank-targets.tsv')
protein_df.to_csv(path, sep='\t', index=False)

# %%
protein_df.nunique()
# Out:
# actions          104
# category           4
# drugbank_id     7836
# known_action       3
# organism         541
# uniprot_id      4981
# dtype: int64

# %%
protein_df[protein_df['organism'] == 'Humans'].nunique()
# Out:
# actions          103
# category           4
# drugbank_id     6203
# known_action       3
# organism           1
# uniprot_id      3001
# dtype: int64

# %%
protein_df[protein_df['organism'] == 'Humans']['category'].value_counts()
# Out:
# target         14333
# enzyme          4813
# transporter     2718
# carrier          689
# Name: category, dtype: int64

# %%
evidence = []                                                                                                                                                                
references = target.find('{http://www.drugbank.ca}references')                                                                                                               
for article in references.find('{http://www.drugbank.ca}articles'):                                                                                                          
    pmid = article.find('{http://www.drugbank.ca}pubmed-id').text                                                                                                            
    text = article.find('{http://www.drugbank.ca}citation').text                                                                                                             
    evidence.append({'source': 'DrugBank', 'pmid': pmid, 'text': text})

# %% [markdown]
# ## Try the CSV downloaded from drugbank(?)

# %%
drugbank_csv = "/data/jeff-law/projects/2020-03-covid-19/SARS-CoV-2-network-analysis/datasets/testing/drugbank/drug-links.csv"
df = pd.read_csv(drugbank_csv)
df.head()
# Out:
#   DrugBank ID                 Name   CAS Number    Drug Type KEGG Compound ID  \
# 0     DB00001            Lepirudin  138068-37-8  BiotechDrug              NaN
# 1     DB00002            Cetuximab  205923-56-4  BiotechDrug              NaN
# 2     DB00003         Dornase alfa  143831-71-4  BiotechDrug              NaN
# 3     DB00004  Denileukin diftitox  173146-27-5  BiotechDrug              NaN
# 4     DB00005           Etanercept  185243-69-0  BiotechDrug           C07897
#
#   KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  ChEBI ID  \
# 0       D06880                  NaN            46507011.0       NaN
# 1       D03455                  NaN            46507042.0       NaN
# 2          NaN                  NaN            46507792.0       NaN
# 3          NaN                  NaN            46506950.0       NaN
# 4       D00742                  NaN            46506732.0       NaN
#
#    PharmGKB ID    ...     GenBank ID DPD ID  \
# 0     PA450195    ...            NaN  11916
# 1      PA10040    ...         J00228  13175
# 2      PA10318    ...         M55983    650
# 3  PA164750594    ...         V01536    NaN
# 4     PA449515    ...         M32315  12032
#
#                                          RxList Link Pdrhealth Link  \
# 0    http://www.rxlist.com/cgi/generic/lepirudin.htm            NaN
# 1     http://www.rxlist.com/cgi/generic3/erbitux.htm            NaN
# 2    http://www.rxlist.com/cgi/generic/pulmozyme.htm            NaN
# 3  http://www.rxlist.com/cgi/generic2/denileukin.htm            NaN
# 4   http://www.rxlist.com/cgi/generic/etanercept.htm            NaN
#
#           Wikipedia ID                                     Drugs.com Link  \
# 0            Lepirudin            http://www.drugs.com/cdi/lepirudin.html
# 1            Cetuximab            http://www.drugs.com/cdi/cetuximab.html
# 2         Dornase_alfa         http://www.drugs.com/cdi/dornase-alfa.html
# 3  Denileukin_diftitox  http://www.drugs.com/cdi/denileukin-diftitox.html
# 4           Etanercept           http://www.drugs.com/cdi/etanercept.html
#
#   NDC ID ChemSpider ID BindingDB ID     TTD ID
# 0    NaN           NaN          NaN  DAP000541
# 1    NaN           NaN          NaN  DNC000788
# 2    NaN           NaN          NaN  DAP000981
# 3    NaN           NaN          NaN  DAP001098
# 4    NaN           NaN          NaN  DNC000605
#
# [5 rows x 23 columns]

# %%
print(df['DrugBank ID'].nunique())
print(df['Name'].nunique())
print(df['UniProt ID'].nunique())
# Out:
# 13475
# 13475
# 66

# %%
print(df.columns)
# Out:
# Index(['DrugBank ID', 'Name', 'CAS Number', 'Drug Type', 'KEGG Compound ID',
#        'KEGG Drug ID', 'PubChem Compound ID', 'PubChem Substance ID',
#        'ChEBI ID', 'PharmGKB ID', 'HET ID', 'UniProt ID', 'UniProt Title',
#        'GenBank ID', 'DPD ID', 'RxList Link', 'Pdrhealth Link', 'Wikipedia ID',
#        'Drugs.com Link', 'NDC ID', 'ChemSpider ID', 'BindingDB ID', 'TTD ID'],
#       dtype='object')
